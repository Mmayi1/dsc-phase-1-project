# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Name: Alpha Guya
# * Student pace: part time
# * Scheduled project review date/time:
# * Instructor name: Antony Muiko
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
# checking list of files
# !ls
# Out:
# CONTRIBUTING.md
# LICENSE.md
# README.md
# awesome.gif
# bom.movie_gross.csv
# name.basics.csv
# rt.movie_info.tsv
# rt.reviews.tsv
# student.ipynb
# title.akas.csv
# title.basics.csv
# title.crew.csv
# title.principals.csv
# title.ratings.csv
# tmdb.movies.csv
# tn.movie_budgets.csv
# zippedData

# %%
#Importing required libraries
#Pandas for data wrangling and manipulation
import pandas as pd

#Matplotlib and Seaborn for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing my work data set
moviegross_df = pd.read_csv("bom.movie_gross.csv")
moviegross_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#DATA UNDERSTANDING
#Investigating the bom movie_gross ratings data
moviegross_df.info()
#All the data types are as needed except for foreign_gross which should be an integer
#There are  columns with missing values ie 2, 3 and 4
#records are 3387 with 5 columns
#foreign_gross column is of wrong type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
moviegross_df.shape
# Out:
# (3387, 5)

# %%
#Checking for duplicates in the dataframe:
moviegross_df.duplicated().sum()

#The data has no duplicate values
# Out:
# 0

# %%
moviegross_df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
moviegross_df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
moviegross_df.describe().tail(15)
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
moviegross_df.tail(15)
# Out:
#                                                   title      studio  \
# 3372                           Gabriel and the Mountain      Strand
# 3373                  Marlina the Murderer in Four Acts       Icar.
# 3374                                         The Escape         IFC
# 3375  How Victor 'The Garlic' Took Alexey 'The Stud'...     CARUSEL
# 3376        Lou Andreas-Salomé, the Audacity to be Free         CLS
# 3377                                    Let Yourself Go        Men.
# 3378                                      Hannah (2018)         PDF
# 3379                                           Souvenir      Strand
# 3380                       Furious (Legend of Kolovrat)     CARUSEL
# 3381                                Beauty and the Dogs       Osci.
# 3382                                          The Quake       Magn.
# 3383                        Edward II (2018 re-release)          FM
# 3384                                           El Pacto        Sony
# ...

# %%
moviegross_df.head(15)
#Observing the 1st 15 records generally
# Out:
#                                                 title studio  domestic_gross  \
# 0                                         Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland (2010)     BV     334200000.0
# 2         Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                           Inception     WB     292600000.0
# 4                                 Shrek Forever After   P/DW     238700000.0
# 5                          The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                          Iron Man 2   Par.     312400000.0
# 7                                             Tangled     BV     200800000.0
# 8                                       Despicable Me   Uni.     251500000.0
# 9                            How to Train Your Dragon   P/DW     217600000.0
# 10                         Clash of the Titans (2010)     WB     163200000.0
# ...

# %%
# converting the foreign_gross to integer/ correcting the data type error 
moviegross_df['foreign_gross'] = moviegross_df['foreign_gross'].str.replace(",","").apply(float)

moviegross_df['foreign_gross'].dtype
# Out:
# dtype('float64')

# %%
#Declare a dataset that sorts domestic_gross in descending order
#Identifying the top five studios by domestic _gross earned by movie titles
df1 = moviegross_df.sort_values(by = "domestic_gross", ascending = False)
df1
# Out:
#                                title  studio  domestic_gross  foreign_gross  \
# 1872    Star Wars: The Force Awakens      BV     936700000.0         1131.6
# 3080                   Black Panther      BV     700100000.0    646900000.0
# 3079          Avengers: Infinity War      BV     678800000.0         1369.5
# 1873                  Jurassic World    Uni.     652300000.0         1019.4
# 727            Marvel's The Avengers      BV     623400000.0    895500000.0
# ...                              ...     ...             ...            ...
# 1975  Surprise - Journey To The West      AR             NaN     49600000.0
# 2392             Finding Mr. Right 2      CL             NaN    114700000.0
# 2468                          Solace     LGP             NaN     22400000.0
# 2595                           Viral  W/Dim.             NaN       552000.0
# 2825                Secret Superstar     NaN             NaN    122000000.0
#
#       year
# 1872  2015
# 3080  2018
# 3079  2018
# ...

# %%
df1.head()
# Out:
#                              title studio  domestic_gross  foreign_gross  year
# 1872  Star Wars: The Force Awakens     BV     936700000.0         1131.6  2015
# 3080                 Black Panther     BV     700100000.0    646900000.0  2018
# 3079        Avengers: Infinity War     BV     678800000.0         1369.5  2018
# 1873                Jurassic World   Uni.     652300000.0         1019.4  2015
# 727          Marvel's The Avengers     BV     623400000.0    895500000.0  2012

# %%
df1["studio"].value_counts().head(10)
df2 = pd.DataFrame(df1["studio"].value_counts().head(10))
df2["studio2"] = df2.index
#codes that map data to the performance

# %%
 df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, IFC to Par.
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   studio   10 non-null     int64
#  1   studio2  10 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 240.0+ bytes

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.barplot(x=df2['studio'],y=df2['studio2'])

plt.xlabel('count') 
plt.ylabel('studio') 
plt.title('Top ten studios in domestic gross revenue generation')
plt.show()
#IFC, Uni, WB, Fox, Magn, SPC, Sony, BV, LGF and Par with IFC leading the studios.

# %%
df1["studio"].value_counts().tail(12)
df2 = pd.DataFrame(df1["studio"].value_counts().tail(12))
df2["studio2"] = df2.index

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(x=df2['studio'],y=df2['studio2'])

plt.xlabel('count') 
plt.ylabel('studio') 
plt.title('Bottom twelve studios in domestic gross revenue generation')
plt.show()
#Libre, Truly, App., PaIT upto KKM are the least 12 performing studios interms of gross domestic revenue generation all at the same level.

# %%
#RECOMMENDATIONS
#The top 10 studios should continue with their respective strategies put in place to maintain their top gross domestic product earningsand even improve further.
#The bottom studios should put in place interventions to ensure they improve their gross domestic earnings.
#The bottom 12 studios shoulde be merged to reduce their operational costs and maximise on their gross domestic revenue generation.
#The bottom 12 studios should be merged with the top 10 gross domestic revenue generating studios that they may well versed in dealings geared towards reaping the optimum gross domestic revenue from the film industry.
